# %%
import pandas as pd

# %%
data = {'Name':['siva','arun','venu','roja'],
       'Age':[34,45,32,29],
       'City':['chennai','trichy','pondy','hosur']}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Name  Age     City
# 0  siva   34  chennai
# 1  arun   45   trichy
# 2  venu   32    pondy
# 3  roja   29    hosur

# %%
numbers = [10,20,30,40,50]

# %%
s = pd.Series(numbers)

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
