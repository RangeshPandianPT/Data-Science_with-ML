# %%
import Pandas_Math as pdm

# %%
pdm.addition(7,8)
# Out:
# 15

# %%
pdm.subtraction(10,4)
# Out:
# 6

# %%
pdm.multiplication(10,3)
# Out:
# 30

# %%
pdm.division(10,5)
# Out:
# 2.0

# %% [markdown]
# ## Thus we have created our own library and imported here in our notebook !!!
