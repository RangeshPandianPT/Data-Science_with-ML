# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\range\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\range\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\range\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id="5d8b9ceb8a474f75b06f0e26ef5669e7",
        client_secret="1a738d346a2f420bb8247a989a77d08f",
        redirect_uri="https://abcd1234.ngrok.io/callback",
        scope="playlist-read-private"
    )
)

print("Authentication successful")
# Out:
# Authentication successful

# %%
track = sp.track("3n3Ppam7vgaVa1iaRUc9Lp")
print(track["name"])
# Out:
# Enter the URL you were redirected to:  https://abcd1234.ngrok.io/callback?code=AQCuCDPpLsUmtCI_d9wvCqtBQ5ednUsFLgeaHi7TMp3Zm3BVr77RPD4OPZGGgM9jfRIqDNXrfBU-LFe2rFgBqMEQnSO3kZMEHq2eeFJ0f3VGfPtYUwV0NwtI4zWbLbmBzdX7NVaGxST_GXtup3A3uqPwBWvugqbkaHoJUt3-OLP8-N9A1oW93iC8sDmQ_VSqETam1QfIlC-iXmAidQ
# Mr. Brightside

# %%
track_ids = [
    "3n3Ppam7vgaVa1iaRUc9Lp",  # Mr. Brightside
    "7ouMYWpwJ422jRcDASZB7P",  # Numb
    "0VjIjW4GlUZAMYd2vXMi3b"   # Blinding Lights
]

# %%
SpotifyOAuth(
    client_id="YOUR_CLIENT_ID",
    client_secret="YOUR_CLIENT_SECRET",
    redirect_uri="http://localhost:9090/callback",
    scope="user-read-private"
)

# %%
from spotipy.oauth2 import SpotifyOAuth
import spotipy

auth = SpotifyOAuth(
    client_id="YOUR_CLIENT_ID",
    client_secret="YOUR_CLIENT_SECRET",
    redirect_uri="http://localhost:9090/callback",
    open_browser=True
)

token = auth.get_access_token(as_dict=False)

sp = spotipy.Spotify(auth=token)

# %%
print(sp.audio_features(["3n3Ppam7vgaVa1iaRUc9Lp"]))
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=3n3Ppam7vgaVa1iaRUc9Lp with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
track_ids = [
    "3n3Ppam7vgaVa1iaRUc9Lp",
    "7ouMYWpwJ422jRcDASZB7P",
    "0VjIjW4GlUZAMYd2vXMi3b"
]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id="5d8b9ceb8a474f75b06f0e26ef5669e7",
        client_secret="1a738d346a2f420bb8247a989a77d08f"
    )
)

# %%
features = sp.audio_features(track_ids)

data = []
for f in features:
    data.append({
        "tempo": f["tempo"],
        "energy": f["energy"],
        "danceability": f["danceability"]
    })

df = pd.DataFrame(data)
print(df)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=3n3Ppam7vgaVa1iaRUc9Lp,7ouMYWpwJ422jRcDASZB7P,0VjIjW4GlUZAMYd2vXMi3b with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...
